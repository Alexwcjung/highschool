# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexwcjung/highschool/blob/main/%EC%BD%94%EB%94%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # gTTS setting

# %%
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio, display

# %%
def tts(txt):
  tts = gTTS(txt, lang='en')
  tts.save("sample.mp3")
  return Audio("/content/sample.mp3")

# %%
mytext = input("Type text: ")
tts(mytext)
# Out:
# Type text: Jonathan Livingston Seagull is different from other seagulls. Instead of fighting over food, he spends his time learning to fly
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Install the googletrans library
# !pip install googletrans==4.0.0-rc1

# Import the Translator class from googletrans
from googletrans import Translator

# Function to translate English text to Korean
def translate_to_korean(text):
    translator = Translator()
    translation = translator.translate(text, src='en', dest='ko')
    return translation.text

# Get user input
english_text = input("Enter the text in English: ")

# Translate the input text
korean_text = translate_to_korean(english_text)
print(f"English: {english_text}")
print(f"Korean: {korean_text}")
